# %% [markdown]
# **Data Science and Machine Learning course - Batch-3**
#
# **Assignment-3 - Data Visualization**
#
# **Submission Date: 09/06/2024**
#
# **General Instructions for Assignment submission**
# - After completing the assignment work, please zip all the files - Python code with results, screenshots, text file, etc. any file please zip all, and upload as a single zip file.
# - That zip file's name, keep it based on this template "**dsmlbatch3_asm3_yourfirstname_yourinitial.zip**"
# - Upload File option will be present after clicking the "Attempt Now" button in the Assignments page
# - For clarity about the Assignment, refer to class video recordings or ask questions during the Doubt Clearing Session
#
# --------------------------------

# %% [markdown]
# ### Initial understanding about this Assignment Dataset

# %% [markdown]
# **Kaggle:**
# - Kaggle is a data science competition platform and online community of data scientists and machine learning practitioners under Google LLC.
# - Kaggle enables users to find and publish datasets, explore and build models in a web-based data science environment, work with other data scientists and machine learning engineers, and enter competitions to solve data science challenges.
# - Refer: https://en.wikipedia.org/wiki/Kaggle
#
# <br>
#
# **About Kaggle Dataset Reference for current assignment**
# - **Username**: equilibriumm
# - **Dataset title**: Sleep Efficiency Dataset
# - **Dataset link**: https://www.kaggle.com/datasets/equilibriumm/sleep-efficiency
# - **Dataset description**: The dataset contains information about a group of test subjects and their sleep patterns.
#     - Each test subject is identified by a unique "**Subject ID**" and their **age** and **gender** are also recorded.
#     - The "**Bedtime**" and "**Wakeup time**" features indicate when each subject goes to bed and wakes up each day, and the "**Sleep duration**" feature records the total amount of time each subject slept in hours.
#     - The "**Sleep efficiency**" feature is a measure of the proportion of time spent in bed that is actually spent asleep.
#     - The "**REM sleep percentage**", "**Deep sleep percentage**", and "**Light sleep percentage**" features indicate the amount of time each subject spent in each stage of sleep.
#     - The "**Awakenings**" feature records the number of times each subject wakes up during the night.
#     - Additionally, the dataset includes information about each subject's **caffeine** and **alcohol** consumption in the 24 hours prior to bedtime, their **smoking** status, and their **exercise** frequency.
# - **Dataset columns count**: 15
# - **Dataset rows count**: 452
#
# <br>
#
# **Dataset Authors:**
# The dataset provided was collected as part of a study conducted in Morocco by a group of artificial intelligence engineering students from ENSIAS.
#
# **Dataset Collection Methodology:**
# The study aimed to investigate the impact of lifestyle factors such as caffeine, alcohol, and exercise on sleep patterns and sleep quality. The team recruited participants from the local community and collected data over a period of several months. The data was collected using a combination of self-reported surveys, actigraphy, and polysomnography which is a sleep monitoring technique.
#
# **Data Analysis Goal:**
# The data was then analyzed to **understand the relationship between lifestyle factors** and **sleep patterns** and to identify any potential areas for intervention to improve sleep.

# %% [markdown]
# ### Data Visualization assignment tasks
#
# 1. Create an Account in Kaggle with your personal email id
# 2. Download the dataset from this link in Kaggle: https://www.kaggle.com/datasets/equilibriumm/sleep-efficiency
# 3. Use that Dataset, **To Understand the relationship between lifestyle factors** and **sleep patterns**. Apply all the concepts learnt in the course, and **Explain your Understandings in few words after every figure**. Use **minimum 5 of the following figure types** for Visualization learnt from this course:
#     - Line plot
#     - Scatter plot
#     - Bar chart
#     - Pie chart
#     - Histogram chart
#     - Box plot
#     - Heatmap chart
#     - 3D scatter plot
#     - Radar chart

# %% [markdown]
# Create pandas dataframe from Sleep efficiency data set.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_style("whitegrid", {'grid.linestyle': '--'})

df = pd.read_csv("Sleep_Efficiency.csv")
df.head(2)
# Out:
#    ID  Age  Gender           Bedtime       Wakeup time  Sleep duration  \
# 0   1   65  Female  06-03-2021 01:00  06-03-2021 07:00             6.0
# 1   2   69    Male  05-12-2021 02:00  05-12-2021 09:00             7.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# 0                      12         0.0                   0.0
# 1                      53         3.0                   0.0
#
#    Alcohol consumption Smoking status  Exercise frequency
# 0                  0.0            Yes                 3.0
# 1                  3.0            Yes                 3.0

# %%
df.describe()
# Out:
#                ID         Age  Sleep duration  Sleep efficiency  \
# count  452.000000  452.000000      452.000000        452.000000
# mean   226.500000   40.285398        7.465708          0.788916
# std    130.625419   13.172250        0.866625          0.135237
# min      1.000000    9.000000        5.000000          0.500000
# 25%    113.750000   29.000000        7.000000          0.697500
# 50%    226.500000   40.000000        7.500000          0.820000
# 75%    339.250000   52.000000        8.000000          0.900000
# max    452.000000   69.000000       10.000000          0.990000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count            452.000000             452.000000              452.000000
# mean              22.615044              52.823009               24.561947
# std                3.525963              15.654235               15.313665
# min               15.000000              18.000000                7.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       14
# Smoking status             0
# Exercise frequency         6
# dtype: int64

# %%
df.rename(columns = {'Wakeup time':'Wakeup_time', 'Sleep duration':'Sleep_duration ',"Sleep efficiency":"Sleep_efficiency",
                     "REM sleep percentage":"REM_sleep_percentage","Deep sleep percentage":"Deep_sleep_percentage",
                     "Light sleep percentage":"Light_sleep_percentage","Caffeine consumption":"Caffeine_consumption",
                     "Alcohol consumption":"Alcohol_consumption","Smoking status":"Smoking_status",
                     "Exercise frequency":"Exercise_frequency"}, 
          inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup_time             452 non-null    object
#  5   Sleep_duration          452 non-null    float64
#  6   Sleep_efficiency        452 non-null    float64
#  7   REM_sleep_percentage    452 non-null    int64
#  8   Deep_sleep_percentage   452 non-null    int64
#  9   Light_sleep_percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine_consumption    427 non-null    float64
#  12  Alcohol_consumption     438 non-null    float64
#  13  Smoking_status          452 non-null    object
# ...

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      228
# Female    224
# Name: count, dtype: int64

# %% [markdown]
# **The below Pie chart shows the Men's & Women's count in Sleep Efficiency Dataset.**

# %%
plt.pie([df.Gender.value_counts()["Female"],df.Gender.value_counts()["Male"]], labels=["Female","Male"], explode=[0,0.1], colors=["pink","lightgreen"], autopct='%1.1f%%')
plt.title("Men's & Women's count in Sleep Efficiency Dataset ")
plt.legend([df.Gender.value_counts()["Female"],df.Gender.value_counts()["Male"]])
plt.show()

# %% [markdown]
# This pie chart shows that in the sleep_efficiency dataset, 224 records are female's subjects and 228 records are male's subjects.

# %% [markdown]
# **The below line chart shows women's sleep efficiency Vs men's sleep efficiency**

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5), squeeze=False)   
df_female = df[df["Gender"] == "Female"]
df_female=df_female.sort_values(['Age', 'Sleep_efficiency'], ascending=[True, True])
axes[0][0].plot(df_female["Age"], df_female["Sleep_efficiency"], ls = '-', marker='o', ms = 3, c = 'pink')
axes[0][0].set_xlabel("Female_age")
axes[0][0].set_ylabel("Sleep_efficiency")
axes[0][0].set_title("women's sleep efficiency")

df_male = df[df["Gender"] == "Male"]
df_male=df_male.sort_values(['Age', 'Sleep_efficiency'], ascending=[True, True])
axes[0][1].plot(df_male["Age"], df_male["Sleep_efficiency"], c = 'lightGreen', linestyle = 'dotted', marker='o', ms=3)
axes[0][1].set_xlabel("Male_age")
axes[0][1].set_ylabel("Sleep_efficiency")
axes[0][1].set_title("Men's sleep efficiency")

fig.set_tight_layout("w_pad")

# %%
df_female.Gender.value_counts()
# Out:
# Gender
# Female    224
# Name: count, dtype: int64

# %%
df_male.Gender.value_counts()
# Out:
# Gender
# Male    228
# Name: count, dtype: int64

# %% [markdown]
# **Age vs Sleep efficiency**

# %%
sns.lineplot(data=df, x="Age", y="Sleep_efficiency",  hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='Sleep_efficiency'>

# %% [markdown]
# These charts shows that women have high sleep efficiency between 40 and 50, and men have high sleep efficiency between 65 and 68.

# %% [markdown]
# **Below box plot shows Awakenings vs Sleep_efficiency**

# %%
df.boxplot(by ='Awakenings', column =['Sleep_efficiency'], grid = True)     #, grid = False or True by default
plt.title("Awakenings vs Sleep_efficiency", fontsize=10)
plt.ylabel("Sleep_efficiency")
# Out:
# Text(0, 0.5, 'Sleep_efficiency')

# %% [markdown]
# This box plot shows that awakening between sleeps is disturbing sleep efficiency, as awakening increases sleep efficiency, which is decreasing.

# %%
fig, axes = plt.subplots(1,2,figsize=(20,5))
sns.barplot(x="Awakenings", y="Sleep_efficiency", data=df, hue="Gender", ax=axes[0])
sns.boxplot(x="Awakenings", y="Age", data=df, hue="Gender", ax=axes[1])
# Out:
# <Axes: xlabel='Awakenings', ylabel='Age'>

# %% [markdown]
# 0 awakenings has good sleep_efficency and next box plot shows that no much correlation between age and awakenings.

# %% [markdown]
# **Below histogram shows number of smokers and non-smokers and how the smoke affects the sleep efficiency**

# %%
df.Smoking_status.value_counts()
# Out:
# Smoking_status
# No     298
# Yes    154
# Name: count, dtype: int64

# %% [markdown]
# Non-smokers have good sleep efficiency

# %%
import matplotlib.pyplot as plt 
fig, axes = plt.subplots(2, 2, figsize=(8,8), squeeze=False)   

# sns.set_style("whitegrid", {'grid.linestyle': '-.'}) 

axes[0][0].boxplot(df["Sleep_efficiency"])
axes[0][0].set_ylabel("Sleep_efficiency", color="black",fontsize=10)
axes[0][0].set_title("Box plot for Sleep_efficiency", color="black",fontsize=10)

sns.boxplot(df['Sleep_efficiency'], ax=axes[0][1])   
sns.set_style("whitegrid", {'grid.linestyle': '--'})
axes[0][1].set_title("sns Box plot for Sleep_efficiency", fontsize=10)
axes[0][1].set_ylabel("Sleep_efficiency")

axes[1][0].hist(df["Smoking_status"])
axes[1][0].set_xlabel("Smoking_status")
axes[1][0].set_ylabel("frequency")
axes[1][0].set_title("Histogram - Frequency distribution of Smoking_status", fontsize=10)

sns.boxplot(data=df,x="Smoking_status",y="Sleep_efficiency", color="coral", ax=axes[1][1])
axes[1][1].set_xlabel("Yes or No", color="black",fontsize=10)
axes[1][1].set_ylabel("Sleep_efficiency", color="black",fontsize=10)
axes[1][1].set_title("Sleep_efficiency for smokers and non-smokers", color="black",fontsize=10)


fig.set_tight_layout("w_pad")

# %% [markdown]
# Smoking_status counts
# No -->    298
# Yes -->   154
#
# Non-smokers have good sleep efficiency than smokers

# %%
import statistics
print("median", statistics.median(df["Sleep_efficiency"]))
print("mean", statistics.mean(df["Sleep_efficiency"]))
print("mode", statistics.mode(df["Sleep_efficiency"]))
print("min", min(df["Sleep_efficiency"]))
print("max", max(df["Sleep_efficiency"]))
# Out:
# median 0.82
# mean 0.7889159292035398
# mode 0.9
# min 0.5
# max 0.99

# %%
# Dataframe has the quantile function:

Q1 = df["Sleep_efficiency"].quantile(0.25)
print("25% of Sleep_efficiency : ", Q1)
Q3 = df["Sleep_efficiency"].quantile(0.75)
print("75% of Sleep_efficiency : ", Q3)

#In statistics, the upper and lower fences represent the cut-off values for upper and lower outliers in a dataset. 
IQR = Q3 - Q1
Lower_Fence = Q1 - (1.5 * IQR)
Upper_Fence = Q3 + (1.5 * IQR)
print("Lower_Fence of Sleep_efficiency : ", Lower_Fence)
print("Upper_Fence of Sleep_efficiency : ", Upper_Fence)

maxV = max(df.Sleep_efficiency[df.Sleep_efficiency<Upper_Fence])
minV = min(df.Sleep_efficiency[df.Sleep_efficiency>Lower_Fence])

print("min: ", minV)
print("max: ", maxV)
# Out:
# 25% of Sleep_efficiency :  0.6975
# 75% of Sleep_efficiency :  0.9
# Lower_Fence of Sleep_efficiency :  0.39375
# Upper_Fence of Sleep_efficiency :  1.20375
# min:  0.5
# max:  0.99

# %% [markdown]
# **To get the correlation among the columns of our DataFrame**

# %%
import seaborn as sns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup_time             452 non-null    object
#  5   Sleep_duration          452 non-null    float64
#  6   Sleep_efficiency        452 non-null    float64
#  7   REM_sleep_percentage    452 non-null    int64
#  8   Deep_sleep_percentage   452 non-null    int64
#  9   Light_sleep_percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine_consumption    427 non-null    float64
#  12  Alcohol_consumption     438 non-null    float64
#  13  Smoking_status          452 non-null    object
# ...

# %%
new_df = df.drop(["Smoking_status", "Light_sleep_percentage", "Deep_sleep_percentage", "REM_sleep_percentage", "Wakeup_time","Bedtime","Gender","ID"], axis=1)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388 entries, 0 to 451
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   388 non-null    int64
#  1   Sleep_duration        388 non-null    float64
#  2   Sleep_efficiency      388 non-null    float64
#  3   Awakenings            388 non-null    float64
#  4   Caffeine_consumption  388 non-null    float64
#  5   Alcohol_consumption   388 non-null    float64
#  6   Exercise_frequency    388 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 24.2 KB

# %%
new_df.shape
# Out:
# (452, 7)

# %%
new_df.dropna(inplace=True)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388 entries, 0 to 451
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   388 non-null    int64
#  1   Sleep_duration        388 non-null    float64
#  2   Sleep_efficiency      388 non-null    float64
#  3   Awakenings            388 non-null    float64
#  4   Caffeine_consumption  388 non-null    float64
#  5   Alcohol_consumption   388 non-null    float64
#  6   Exercise_frequency    388 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 24.2 KB

# %%
# To get the correlation among the columns of our DataFrame
new_df_correlations = new_df.corr()

# %%
new_df_correlations
# Out:
#                            Age  Sleep_duration   Sleep_efficiency  Awakenings  \
# Age                   1.000000        -0.065951          0.124093   -0.004006
# Sleep_duration       -0.065951         1.000000         -0.019164   -0.009162
# Sleep_efficiency      0.124093        -0.019164          1.000000   -0.567885
# Awakenings           -0.004006        -0.009162         -0.567885    1.000000
# Caffeine_consumption -0.169057        -0.030922          0.070804   -0.112922
# Alcohol_consumption   0.069295        -0.048436         -0.397012    0.210017
# Exercise_frequency    0.071241        -0.046671          0.266050   -0.231464
#
#                       Caffeine_consumption  Alcohol_consumption  \
# Age                              -0.169057             0.069295
# Sleep_duration                   -0.030922            -0.048436
# Sleep_efficiency                  0.070804            -0.397012
# Awakenings                       -0.112922             0.210017
# ...

# %%
sns.heatmap(new_df_correlations.round(2), annot=True, cmap="coolwarm")

# 1.000000 - highly positively correlated
# towards 0 - less correlation
# -0.287739 - highly negatively correlated
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# number of missing values for each column
print("Number of missing values:\n")
print("by column:")
nan_val_count = df.isnull().sum()
print(nan_val_count, "\n")

som = nan_val_count.sum()
print("Total:", som, end= " ~")
print(round(som / (df.shape[0] * df.shape[1]) * 100), "% of the dataset")
# Out:
# Number of missing values:
#
# by column:
# ID                        0
# Age                       0
# Gender                    0
# Bedtime                   0
# Wakeup_time               0
# Sleep_duration            0
# Sleep_efficiency          0
# REM_sleep_percentage      0
# Deep_sleep_percentage     0
# Light_sleep_percentage    0
# Awakenings                0
# Caffeine_consumption      0
# Alcohol_consumption       0
# Smoking_status            0
# Exercise_frequency        0
# dtype: int64
#
# Total: 0 ~0 % of the dataset

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Bedtime', 'Wakeup_time', 'Sleep_duration ',
#        'Sleep_efficiency', 'REM_sleep_percentage', 'Deep_sleep_percentage',
#        'Light_sleep_percentage', 'Awakenings', 'Caffeine_consumption',
#        'Alcohol_consumption', 'Smoking_status', 'Exercise_frequency'],
#       dtype='object')

# %%
# replace null values with mean
df['Awakenings'].fillna(df['Awakenings'].mean(), inplace=True)
df['Caffeine_consumption'].fillna(df['Caffeine_consumption'].mean(), inplace=True)
df['Alcohol_consumption'].fillna(df['Alcohol_consumption'].mean(), inplace=True)
df['Exercise_frequency'].fillna(df['Exercise_frequency'].mean(), inplace=True)

# %%
# cheching for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# drop the ID column
df.drop('ID', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     452 non-null    int64
#  1   Gender                  452 non-null    object
#  2   Bedtime                 452 non-null    object
#  3   Wakeup_time             452 non-null    object
#  4   Sleep_duration          452 non-null    float64
#  5   Sleep_efficiency        452 non-null    float64
#  6   REM_sleep_percentage    452 non-null    int64
#  7   Deep_sleep_percentage   452 non-null    int64
#  8   Light_sleep_percentage  452 non-null    int64
#  9   Awakenings              452 non-null    float64
#  10  Caffeine_consumption    452 non-null    float64
#  11  Alcohol_consumption     452 non-null    float64
#  12  Smoking_status          452 non-null    object
#  13  Exercise_frequency      452 non-null    float64
# ...

# %%
from IPython.display import display, HTML
def create_scrollable_table(df, table_id, title):
    html = f'<h3>{title}</h3>'
    html += f'<div id="{table_id}" style="height:200px; overflow:auto;">'
    html += df.to_html()
    html += '</div>'
    return html

# %%
sleep_efficiency_df_test = create_scrollable_table(df, 'sleep_efficiency_df Test', 'sleep_efficiency_df Test')
display(HTML(sleep_efficiency_df_test))
# Out:
# <h3>sleep_efficiency_df Test</h3><div id="sleep_efficiency_df Test" style="height:200px; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Gender</th>
#       <th>Bedtime</th>
#       <th>Wakeup_time</th>
#       <th>Sleep_duration</th>
#       <th>Sleep_efficiency</th>
#       <th>REM_sleep_percentage</th>
#       <th>Deep_sleep_percentage</th>
#       <th>Light_sleep_percentage</th>
#       <th>Awakenings</th>
#       <th>Caffeine_consumption</th>
#       <th>Alcohol_consumption</th>
#       <th>Smoking_status</th>
#       <th>Exercise_frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>65</td>
#       <td>Female</td>
#       <td>06-03-2021 01:00</td>
#       <td>06-03-2021 07:00</td>
#       <td>6.0</td>
#       <td>0.88</td>
#       <td>18</td>
#       <td>70</td>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
# ...

# %%
# encoding the categorical data
le = LabelEncoder()

df["Gender"] = le.fit_transform(df["Gender"].astype(str))
df["Smoking_status"] = le.fit_transform(df["Smoking_status"].astype(str))
df["Bedtime"] = le.fit_transform(df["Bedtime"].astype(str))
df["Wakeup_time"] = le.fit_transform(df["Wakeup_time"].astype(str))

# %%
sleep_efficiency_df_test = create_scrollable_table(df, 'sleep_efficiency_df Test', 'sleep_efficiency_df Test')
display(HTML(sleep_efficiency_df_test))
# Out:
# <h3>sleep_efficiency_df Test</h3><div id="sleep_efficiency_df Test" style="height:200px; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Gender</th>
#       <th>Bedtime</th>
#       <th>Wakeup_time</th>
#       <th>Sleep_duration</th>
#       <th>Sleep_efficiency</th>
#       <th>REM_sleep_percentage</th>
#       <th>Deep_sleep_percentage</th>
#       <th>Light_sleep_percentage</th>
#       <th>Awakenings</th>
#       <th>Caffeine_consumption</th>
#       <th>Alcohol_consumption</th>
#       <th>Smoking_status</th>
#       <th>Exercise_frequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>65</td>
#       <td>0</td>
#       <td>76</td>
#       <td>77</td>
#       <td>6.0</td>
#       <td>0.88</td>
#       <td>18</td>
#       <td>70</td>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
# ...

# %%
# plot the correlation matrix
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr.round(2), annot=True, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(12, 6))
# heatmap = sns.heatmap(heart_disease_df.corr(method='pearson'),vmin=-1,vmax=1,annot=True,cmap='flare',annot_kws={"fontsize":14}, fmt='.2f')
heatmap = sns.heatmap(df.corr(method='pearson'),vmin=-1,vmax=1,annot=True,cmap='coolwarm',annot_kws={"fontsize":14}, fmt='.2f')
sns.set(font_scale=2)
plt.title('Correlation of features heatmap',fontsize=15, color='darkblue', pad=20)
plt.xticks(color='darkblue', fontsize=10)
plt.yticks(color='darkblue', fontsize=10)

colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelcolor='darkblue', labelsize=12)

plt.gcf().patch.set_facecolor('lightblue')
plt.show()

# %% [markdown]
# Same columns are high positively correlated.
# Alcohol_consumption and sleep_efficiency are negatively correlated.
# Exercise_frequency and caffeine_consumption are null correlated.
# Light sleep and deep sleep are high negatively correlated.

# %%
#find highly correlated features/columns
threshold = 0.8

mask = (df.corr.abs() > threshold) & (df.corr.abs() < 1.0)
highly_correlated_pairs = [(df.corr.index[i], df.corr.columns[j]) for i in range(len(df.corr.columns)) for j in range(i) if mask.iloc[i,j]]
highly_correlated_pairs

# %%
sns.histplot(df["Sleep_efficiency"], kde=True, fill=False)

plt.legend(["mean", "median", "mode", "Distribution"], loc ="upper right", fontsize="8")
plt.show()

# %% [markdown]
# Below histogram shows Distribution of Sleep Efficiency

# %%
plt.figure(figsize=(10,5))
plt.axvline(df["Sleep_efficiency"].mean(), color="red")
plt.axvline(df["Sleep_efficiency"].median(), color="black")
plt.axvline(list(df["Sleep_efficiency"].mode())[0], color="orange")
plt.xlabel("Sleep_efficiency")
plt.ylabel("frequency")

# Plotting using Matplotlib
# plt.hist(my_normal_series)

# Plotting using Seaborn
#sns.displot(my_normal_series, kde=True)
sns.histplot(df["Sleep_efficiency"], kde=True, fill=False)

plt.legend(["mean", "median", "mode", "Distribution"], loc ="upper right", fontsize="11")
plt.show()

# %%
import statistics
print("median of Sleep_efficiency:  ", statistics.median(df["Sleep_efficiency"]))
print("mean of Sleep_efficiency  :  ", statistics.mean(df["Sleep_efficiency"]))
print("mode of Sleep_efficiency  :  ", statistics.mode(df["Sleep_efficiency"]))
print("min of Sleep_efficiency   :  ", min(df["Sleep_efficiency"]))
print("max of Sleep_efficiency   :  ", max(df["Sleep_efficiency"]))
Q1 = df["Sleep_efficiency"].quantile(0.25)
print("25% of Sleep_efficiency   :  ", Q1)
Q3 = df["Sleep_efficiency"].quantile(0.75)
print("75% of Sleep_efficiency   :  ", Q3)
# Out:
# median of Sleep_efficiency:   0.82
# mean of Sleep_efficiency  :   0.7889159292035398
# mode of Sleep_efficiency  :   0.9
# min of Sleep_efficiency   :   0.5
# max of Sleep_efficiency   :   0.99
# 25% of Sleep_efficiency   :   0.6975
# 75% of Sleep_efficiency   :   0.9

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388 entries, 0 to 451
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   388 non-null    int64
#  1   Sleep_duration        388 non-null    float64
#  2   Sleep_efficiency      388 non-null    float64
#  3   Awakenings            388 non-null    float64
#  4   Caffeine_consumption  388 non-null    float64
#  5   Alcohol_consumption   388 non-null    float64
#  6   Exercise_frequency    388 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 24.2 KB

# %% [markdown]
# ** Comparision of Sleep_efficiency with various columns **

# %%
import matplotlib.pyplot as plt 
fig, axes = plt.subplots(2, 3, figsize=(15,5), squeeze=False)   

axes[0][0].bar(new_df["Age"], new_df["Sleep_efficiency"])
axes[0][0].set_xlabel("Age")
axes[0][0].set_ylabel("Sleep_efficiency")
axes[0][0].set_title("Age and Sleep_efficiency", fontsize=8)

axes[0][1].bar(new_df["Awakenings"], new_df["Sleep_efficiency"], width = 0.5, color = "hotpink")
axes[0][1].set_xlabel("Awakenings")
axes[0][1].set_ylabel("Sleep_efficiency")
axes[0][1].set_title("Awakenings and Sleep_efficiency", fontsize=8)

axes[0][2].bar(new_df["Caffeine_consumption"], new_df["Sleep_efficiency"])
axes[0][2].set_xlabel("Caffeine_consumption")
axes[0][2].set_ylabel("Sleep_efficiency")
axes[0][2].set_title("Caffeine_consumption and Sleep_efficiency", fontsize=8)

axes[1][0].bar(new_df["Alcohol_consumption"], new_df["Sleep_efficiency"], width = 0.5)
axes[1][0].set_xlabel("Alcohol_consumption")
axes[1][0].set_ylabel("Sleep_efficiency")
axes[1][0].set_title("Alcohol_consumption and Sleep_efficiency", fontsize=8)

axes[1][1].bar(new_df["Exercise_frequency"], new_df["Sleep_efficiency"])
axes[1][1].set_xlabel("Exercise_frequency")
axes[1][1].set_ylabel("Sleep_efficiency")
axes[1][1].set_title("Exercise_frequency and Sleep_efficiency", fontsize=8)

# axes[1][2].scatter(new_df["Sleep_duration"], new_df["Sleep_efficiency"])
# axes[1][2].set_xlabel("Sleep_duration")
# axes[1][2].set_ylabel("Sleep_efficiency")
# axes[1][2].set_title("Sleep_duration and Sleep_efficiency")

sns.kdeplot(data=df[['REM_sleep_percentage', 'Deep_sleep_percentage', 'Light_sleep_percentage']], ax=axes[1][2])
axes[1][2].set_title('Distribution of Sleep Stages', fontsize=8)
axes[1][2].set_xlabel('Sleep Percentage')
axes[1][2].set_ylabel('Density')

fig.set_tight_layout("w_pad")

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5), squeeze=False)   

# sns.boxplot(data=df,x="Alcohol_consumption",y="Sleep_efficiency", color="green")
# plt.title("What is the effect of drinking alcohol on sleep efficiency?", color="green",fontsize=10)


sns.boxplot(data=df,x="Alcohol_consumption",y="Sleep_efficiency", color="green", ax=axes[0][0])
axes[0][0].set_title("What is the effect of drinking alcohol on sleep efficiency?", color="green",fontsize=10)


sns.kdeplot(data=df, x="Alcohol_consumption",color="green",fill=True, ax=axes[0][1])
axes[0][1].set_xlabel("Alcohol Consumption", color="green", fontsize=10)
axes[0][1].set_ylabel("frequency", color="green", fontsize=10)
axes[0][1].set_title("Alcohol Consumption Kdeplot", color="green",fontsize=10)

fig.set_tight_layout("w_pad")

# %% [markdown]
# The above chart shows that alcohol consumption reduces the sleep efficiency.

# %%
sns.boxplot(data=df,x="Caffeine_consumption",y="Sleep_efficiency", color="orange")
plt.title("What is the effect of Caffeine_consumption on sleep efficiency?", color="brown",fontsize=10)
plt.show()

# %% [markdown]
# The effect of Caffeine_consumption on sleep efficiency is some what null correlation

# %% [markdown]
# 3D scatter plot for Age Vs Sleep_efficiency Vs Caffeine_consumption.

# %%
import plotly.express as px

fig = px.scatter_3d(df, x='Age', y='Sleep_efficiency', z='Caffeine_consumption',
              color='Gender')
fig.show()

# %% [markdown]
# Radar Chart:
# Below shows that both female & male falls under all age group.

# %%
fig = px.line_polar(df, r='Age', theta='Gender', line_close=True)
#fig.update_traces(fill='toself')
fig.update_traces(fill='tonext')
fig.show()

# %%
import plotly.express as px
fig = px.line_polar(df, r='Gender', theta='Age', line_close=True)
#fig.update_traces(fill='toself')
fig.update_traces(fill='tonext')
fig.show()

# %% [markdown]
# Below radar line chart marks the sleep efficiency for each ID

# %%
fig = px.line_polar(df, r='Sleep_efficiency', theta='ID', line_close=True)
#fig.update_traces(fill='toself')
fig.update_traces(fill='tonext')
fig.show()

# %% [markdown]
# This radar graph chart
# marks the sleep efficiency
# for each ID

# %%
import plotly.graph_objects as go
 
fig = go.Figure(data=go.Scatterpolar(
    r=df["Sleep_efficiency"],
    theta=df["ID"],
    mode='markers',
))
 
fig.show()
